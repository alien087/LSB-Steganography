# %%
from PIL import Image, ImageDraw 
import sys

# %%
def BinaryToDecimal(binary): 
      
    # Using int function to convert to 
    # string    
    string = int(binary, 2) 
      
    return string

# %%
image_cover = Image.open("image_cover.bmp")
ImageDraw.Draw(image_cover)

# %%
bit_image2 = list(image_cover.getdata())
bit_image2[len(bit_image2)-1]
# Out:
# 104

# %%
kata = []
for i in range (((bit_image2[len(bit_image2)-1])*8)-1):
    kata.append(format(bit_image2[i], "08b")[7])

# %%
a = ""
a = a.join(kata)
len(a)
# Out:
# 831

# %%
binary_int = int(a, 2)
byte_number = binary_int.bit_length() + 7 // 8

binary_array = binary_int.to_bytes(byte_number, "big")
ascii_text = binary_array.decode()

print(ascii_text)
# Out:
# apa kabarnya semua temen temen sekalian, saya berharap teman teman semua sehat ya, oke ga nih? okeh dong

# %%
image_cover
# Out:
# <PIL.BmpImagePlugin.BmpImageFile image mode=L size=320x240 at 0x23E5706AFC8>
